# %% [markdown]
# # Bar Graph

# %%
import matplotlib.pyplot as plt
import pandas as pd

  
# Initialize the lists for X and Y
data = pd.read_csv('mobile.csv')

  
df = pd.DataFrame(data)
  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 3])     
# print(X)
# print(Y)
plt.bar(X, Y)
plt.title("Mobile")
plt.xlabel("Rank")
plt.ylabel("Speed")
  
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

  
# Initialize the lists for X and Y
data = pd.read_csv('broadband.csv')
  
df = pd.DataFrame(data)
  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 3])     
# print(X)
# print(Y)
plt.bar(X, Y)
plt.title("Broadband")
plt.xlabel("Rank")
plt.ylabel("Speed")
  
# Show the plot
plt.show()

# %% [markdown]
# # Box Plot

# %%
#import library
import pandas as pd

#add csv file to dataframe
df = pd.read_csv('mobile.csv')

#create boxplot
boxplot = df.boxplot(figsize = (5,5))

# %%
#import library
import pandas as pd

#add csv file to dataframe
df = pd.read_csv('broadband.csv')

#create boxplot
boxplot = df.boxplot(figsize = (5,5))

# %%
plt.boxplot(mobile)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9cd2b462e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9cd2bff340>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9cd2b460a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9cd2bff4f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9cd2bff2b0>],
#  'means': []}

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt 

#add csv file to dataframe
df = pd.read_csv('broadband.csv')

df



#create boxplot
# df.boxplot(df[rank,speed],figsize = (5,5),label=('r','s'))
# Out:
#      rank rank_change          country   speed
# 0       1           -            Chile  212.98
# 1       2           -        Singapore  211.36
# 2       3          +1         Thailand  189.14
# 3       4          -1            China  176.93
# 4       5           -  Hong Kong (SAR)  176.59
# ..    ...         ...              ...     ...
# 177   178           -            Syria    2.99
# 178   179           -     Turkmenistan    2.13
# 179   180           -            Yemen    2.12
# 180   181          +1             Cuba    1.89
# 181   182          -1      Afghanistan    1.85
#
# [182 rows x 4 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt("mobile.csv", delimiter=",")
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
  
df = pd.read_csv("mobile.csv")
# print(df.head(10))

df.style.background_gradient(cmap ='viridis')\
        .set_properties(**{'font-size': '20px'})

rank = ((np.asarray(df['rank'])).reshape(14,10))
speed = ((np.asarray(df['speed'])).reshape(14,10))

result = df.pivot(index='rank',columns='rank_change',values='speed')

labels = (np.asarray(["{0} \n {1:.2f}".format(r,s)
                      for r, s in zip(rank.flatten(),
                                               speed.flatten())])
         ).reshape(14,10)


# Use the heatmap function from the seaborn package
sns.heatmap(result,annot=labels,fmt="",cmap='RdYlGn',linewidths=0.30,ax=ax)

# Display the Pharma Sector Heatmap
plt.show()

# print(rank)
# print(speed)

# data_set = np.random.rand( 10 , 10 )

# ax = sns.heatmap( data_set , linewidth = 0.5 , cmap = 'coolwarm' )
  
# plt.title( "2-D Heat Map" )
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 23>()
#      16 labels = (np.asarray(["{0} \n {1:.2f}".format(r,s)
#      17                       for r, s in zip(rank.flatten(),
#      18                                                speed.flatten())])
#      19          ).reshape(14,10)
#      22 # Use the heatmap function from the seaborn package
# ---> 23 sns.heatmap(result,annot=labels,fmt="",cmap='RdYlGn',linewidths=0.30,ax=ax)
#      25 # Display the Pharma Sector Heatmap
#      26 plt.show()
#
# NameError: name 'ax' is not defined

# %%
sns.heatmap(mobile.csv);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [130], in <cell line: 1>()
# ----> 1 sns.heatmap(mobile.csv)
#
# AttributeError: 'list' object has no attribute 'csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')  # to get seaborn scatter plot

# read the csv file to extract data

data = pd.read_csv('mobile.csv')
view_count = data['speed']
likes = data['rank_change']
ratio = data['rank']

plt.scatter(view_count, likes, s=5, alpha=1, edgecolor='red', linewidth=2)

plt.title(' speed test')
plt.xlabel('speed')
plt.ylabel('rank_change')

plt.tight_layout()
plt.show()

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.svm import svc
  
# reading csv file and extracting class column to y. 
x = pd.read_csv("mobile.csv") 
# a = np.array(x) 
y  = a[:,3] # classes having 0 and 1
mode = svc()

  
# extracting two features 
x = np.column_stack((x.rank_change,x.rank)) 
x.shape # 569 samples and 2 features 
  
print (x),(y)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [38], in <cell line: 4>()
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.svm import svc
#       6 # reading csv file and extracting class column to y.
#       7 x = pd.read_csv("mobile.csv")
#
# ImportError: cannot import name 'svc' from 'sklearn.svm' (/home/jethin/.local/lib/python3.8/site-packages/sklearn/svm/__init__.py)

# %% [markdown]
# # svc model

# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import svc
df = pd.read_csv('mobile.csv')
d= df.values
x= d[:,0:3]
y= d[:,3]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
model=SVC()
model.fit(x_train,y_train)
predict_flower=model.predict(x_test)
print("accuracy :{}".format(accuracy_score(y_test,predict_flower)))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [37], in <cell line: 5>()
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.metrics import accuracy_score
# ----> 5 from sklearn.svm import svc
#       6 df = pd.read_csv('mobile.csv')
#       7 d= df.values
#
# ImportError: cannot import name 'svc' from 'sklearn.svm' (/home/jethin/.local/lib/python3.8/site-packages/sklearn/svm/__init__.py)

# %% [markdown]
# # knn model

# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

attributes=(['rank','rank_change','country','speed'])
df = pd.read_csv('mobile.csv',names=attributes)
# print(df)
x= np.array(df.iloc[:,0:2])
y= np.array(df.iloc[:,2])
# print(x)
print(len(x))
print(len(y))

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=42)
knn=KNeighborsClassifier(n_neighbors=3,n_jobs=-1)
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
print("accuracy :{}".format(accuracy_score(y_test,pred)))

# print(x_train)
# print(x_test)
# print(y_train)            
# print(y_test)
